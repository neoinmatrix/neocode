# %%
import numpy as np
import matplotlib.pyplot as plt
labels=['A','B','C','D']
values=[30,10,50,20]
plt.pie(values,labels=labels,colors=['green','yellow','red','blue'],explode=[0,0.2,0,0.3])
plt.show()
